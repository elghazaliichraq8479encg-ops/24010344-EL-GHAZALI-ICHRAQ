# %% [markdown]
# <a href="https://colab.research.google.com/github/elghazaliichraq8479encg-ops/24010344-EL-GHAZALI-ICHRAQ/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------------------------------------------------------
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter
import os

# Set the path to the file you'd like to load
file_path = "crypto_volatility_dec2025_FINAL_2025-12-09.csv"

# The traceback indicates that the directory is /kaggle/input/crypto-volatility-2025-bitcoin-and-memecoin-bull-run
dataset_path = "/kaggle/input/crypto-volatility-2025-bitcoin-and-memecoin-bull-run"

# List files in the dataset directory to find the correct file name
print(f"Files available in the dataset directory '{dataset_path}':")
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        print(os.path.join(root, file))

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "kanchana1990/crypto-volatility-2025-bitcoin-and-memecoin-bull-run",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# 1. IMPORTATION DES BIBLIOTHÈQUES
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Modules Scikit-Learn pour la modélisation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Configuration pour des graphiques esthétiques
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
import warnings
warnings.filterwarnings('ignore')

print("✓ 1. Bibliothèques importées avec succès.\n")

# ------------------------------------------------------------------------------
# 2. CHARGEMENT DES DONNÉES DEPUIS KAGGLE
# ------------------------------------------------------------------------------
print("2. Chargement du dataset Kaggle...")

# Chargement du dataset de volatilité crypto
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "kanchana1990/crypto-volatility-2025-bitcoin-and-memecoin-bull-run",
    file_path="crypto_volatility_dec2025_FINAL_2025-12-09.csv",
)

print(f"✓ Données chargées avec succès!")
print(f"   Taille du dataset : {df.shape[0]} lignes × {df.shape[1]} colonnes")
print(f"\n   Aperçu des 5 premières lignes :")
print(df.head())
print(f"\n   Types de données :")
print(df.dtypes)
print()

# The rest of the code is commented out for now to focus on loading the dataset correctly.
# It will be uncommented and potentially modified once the file path issue is resolved.
# Out:
# Files available in the dataset directory '/kaggle/input/crypto-volatility-2025-bitcoin-and-memecoin-bull-run':
# /kaggle/input/crypto-volatility-2025-bitcoin-and-memecoin-bull-run/crypto_volatility_dec2025_FINAL_2025-12-09.csv
# Using Colab cache for faster access to the 'crypto-volatility-2025-bitcoin-and-memecoin-bull-run' dataset.
# First 5 records:                    timestamp          open          high           low  \
# 0  2025-12-03 00:00:00+00:00  91345.312500  91345.312500  91345.312500
# 1  2025-12-03 00:01:00+00:00  91382.492188  91382.492188  91382.492188
# 2  2025-12-03 00:02:00+00:00  91402.968750  91402.968750  91402.968750
# 3  2025-12-03 00:03:00+00:00  91364.125000  91364.125000  91364.125000
# 4  2025-12-03 00:05:00+00:00  91294.812500  91294.812500  91294.812500
#
#           close       volume    asset   symbol
# 0  91345.312500          0.0  Bitcoin  BTC-USD
# 1  91382.492188  173711360.0  Bitcoin  BTC-USD
# 2  91402.968750          0.0  Bitcoin  BTC-USD
# ...
